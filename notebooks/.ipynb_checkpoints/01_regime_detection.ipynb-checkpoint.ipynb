# %%
import sys
sys.path.append("..")

from src.data_loader import load_market_data
from src.features import create_features
from src.hmm_model import train_hmm

df = load_market_data()
features_df = create_features(df)

hidden_states, hmm_model, scaler = train_hmm(features_df)

features_df["regime"] = hidden_states
features_df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 4
#       1 import sys
#       2 sys.path.append("..")
# ----> 4 from src.data_loader import load_market_data
#       5 from src.features import create_features
#       6 from src.hmm_model import train_hmm
#
# ImportError: cannot import name 'load_market_data' from 'src.data_loader' (c:\Users\hp\Documents\ML_Projects\market_regime_detection\notebooks\..\src\data_loader.py)

# %%
from src.hmm_model import train_hmm
import numpy as np

hidden_states, hmm_model, scaler = train_hmm(features_df)

features_df["regime"] = hidden_states
features_df["regime"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from src.hmm_model import train_hmm
#       2 import numpy as np
#       4 hidden_states, hmm_model, scaler = train_hmm(features_df)
#
# File c:\Users\hp\Documents\ML_Projects\market_regime_detection\notebooks\..\src\hmm_model.py:1
# ----> 1 import numpy as np
#       2 from hmmlearn.hmm import GaussianHMM
#       3 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'numpy'
